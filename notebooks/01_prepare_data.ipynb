# %% [markdown]
# # Imports

# %%
# Import the necessary packages
import os
import requests
import pandas as pd

# %% [markdown]
# # Download data from justjoin.it API

# %% [markdown]
# Download data from justjoin.it api and save to `csv` file

# %%
request = requests.get("https://justjoin.it/api/offers")
data = request.json()

df = pd.DataFrame.from_dict(data)

# Create dir and export csv file
os.makedirs("../data", exist_ok=True)
df.to_csv("../data/justjoin_jobs.csv")

# %% [markdown]
# # Data Viewing

# %%
df.head()
# Out:
#                           title                  street      city  \
# 0  Młodszy programista Frontend       Konstruktorska, 6  Warszawa
# 1               DevOps Engineer            Inflancka 4a    Warsaw
# 2           DevOps Team Manager            Inflancka 4a  Warszawa
# 3           Product Owner Proxy  Marynarki Polskiej 163    Gdańsk
# 4    Experienced Java Developer           Krakowska 29D   Wrocław
#
#   country_code                    address_text marker_icon workplace_type  \
# 0           PL     Konstruktorska, 6, Warszawa  javascript  partly_remote
# 1           PL            Inflancka 4a, Warsaw      devops  partly_remote
# 2           PL          Inflancka 4a, Warszawa      devops  partly_remote
# 3           PL  Marynarki Polskiej 163, Gdańsk          pm         remote
# 4           PL          Krakowska 29D, Wrocław        java  partly_remote
#
#            company_name                 company_url company_size  \
# 0  TechOcean Sp. z o.o.       https://techocean.pl/          >20
# 1            KMD Poland     http://www.kmdpoland.pl         500+
# 2            KMD Poland     http://www.kmdpoland.pl         500+
# 3              Neoteric          http://neoteric.eu          80+
# 4               Bouncer  https://www.usebouncer.com          3-5
#
#   experience_level    latitude   longitude              published_at  \
# 0           junior  52.1857331  20.9932937  2021-06-22T19:18:47.821Z
# 1              mid  52.2296756  21.0122287  2021-06-22T19:00:08.562Z
# 2           senior  52.2564853  20.9945967  2021-06-22T19:00:08.562Z
# 3              mid  54.3721421  18.6343554  2021-06-22T19:00:08.562Z
# 4              mid   51.091532   17.059592  2021-06-22T19:00:08.562Z
#
#    remote_interview                                                 id  \
# 0             False  techocean-sp-z-o-o-mlodszy-programista-fronten...
# 1              True                  kmd-poland-devops-engineer-warsaw
# 2              True                     kmd-poland-devops-team-manager
# 3              True                       neoteric-product-owner-proxy
# 4              True         bouncer-experienced-java-developer-wroclaw
#
#                                     employment_types  \
# 0  [{'type': 'permanent', 'salary': {'from': 3000...
# 1                  [{'type': 'b2b', 'salary': None}]
# 2            [{'type': 'permanent', 'salary': None}]
# 3  [{'type': 'b2b', 'salary': {'from': 6000, 'to'...
# 4  [{'type': 'b2b', 'salary': {'from': 10000, 'to...
#
#                                     company_logo_url  \
# 0  https://bucket.justjoin.it/offers/company_logo...
# 1  https://bucket.justjoin.it/offers/company_logo...
# 2  https://bucket.justjoin.it/offers/company_logo...
# 3  https://bucket.justjoin.it/offers/company_logo...
# 4  https://bucket.justjoin.it/offers/company_logo...
#
#                                               skills  remote
# 0  [{'name': 'JavaScript', 'level': 2}, {'name': ...   False
# 1  [{'name': 'Azure', 'level': 2}, {'name': 'Soft...   False
# 2  [{'name': 'Software Development', 'level': 5},...   False
# 3                       [{'name': 'JS', 'level': 1}]    True
# 4  [{'name': 'AWS', 'level': 4}, {'name': 'Spring...   False

# %%
# Get info about columns type and non-null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4945 entries, 0 to 4944
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             4945 non-null   object
#  1   street            4940 non-null   object
#  2   city              4945 non-null   object
#  3   country_code      4939 non-null   object
#  4   address_text      4945 non-null   object
#  5   marker_icon       4945 non-null   object
#  6   workplace_type    4945 non-null   object
#  7   company_name      4945 non-null   object
#  8   company_url       4945 non-null   object
#  9   company_size      4945 non-null   object
#  10  experience_level  4945 non-null   object
#  11  latitude          4945 non-null   object
#  12  longitude         4945 non-null   object
#  13  published_at      4945 non-null   object
#  14  remote_interview  4945 non-null   bool
#  15  id                4945 non-null   object
#  16  employment_types  4945 non-null   object
#  17  company_logo_url  4945 non-null   object
#  18  skills            4945 non-null   object
#  19  remote            4945 non-null   bool
# dtypes: bool(2), object(18)
# memory usage: 705.2+ KB

# %% [markdown]
# # Null values

# %%
# Check null values
df.isnull().sum()
# Out:
# title               0
# street              5
# city                0
# country_code        6
# address_text        0
# marker_icon         0
# workplace_type      0
# company_name        0
# company_url         0
# company_size        0
# experience_level    0
# latitude            0
# longitude           0
# published_at        0
# remote_interview    0
# id                  0
# employment_types    0
# company_logo_url    0
# skills              0
# remote              0
# dtype: int64

# %%
# Find null values in country_code column
df.loc[df["country_code"].isnull()]
# Out:
#                                          title                  street  \
# 47      NOC Technician (Tech Support Engineer)             Na Kozłówce
# 227                             .Net Developer  Aleja Jana Pawła II 80
# 588   Junior IT Support Specialist - part time            Ogińskiego 2
# 592                   Senior Software Engineer                  Kraków
# 962                            Specjalista ERP       Chwaszczyńska 135
# 3632                 Senior Web Engineer / Mid     ul. Nałęczowska 36C
#
#            city country_code                      address_text marker_icon  \
# 47       Krakow         None               Na Kozłówce, Krakow     support
# 227    Warszawa         None  Aleja Jana Pawła II 80, Warszawa         net
# 588   Bydgoszcz         None           Ogińskiego 2, Bydgoszcz     support
# 592      Kraków         None                    Kraków, Kraków        java
# 962      Gdynia         None         Chwaszczyńska 135, Gdynia         erp
# 3632     Lublin         None       ul. Nałęczowska 36C, Lublin      python
#
#      workplace_type       company_name  \
# 47    partly_remote          Sperasoft
# 227   partly_remote          GASPOL SA
# 588   partly_remote  Vivid Games S. A.
# 592          remote         dotLinkers
# 962   partly_remote            FLOWAIR
# 3632         remote     Milo Solutions
#
#                                             company_url company_size  \
# 47                               https://sperasoft.com/         300+
# 227                                http://www.gaspol.pl          550
# 588                             https://vividgames.com/           70
# 592                               http://dotlinkers.pl/           17
# 962                               http://www.flowair.pl      100-200
# 3632  https://www.milosolutions.com?utm_source=JustJ...        50-60
#
#      experience_level    latitude   longitude              published_at  \
# 47                mid   51.921253   19.145759  2021-06-22T15:32:23.400Z
# 227               mid   52.253984   20.984017  2021-06-22T13:02:00.000Z
# 588            junior   51.921253   19.145759  2021-06-22T10:00:09.941Z
# 592            senior   51.921253   19.145759  2021-06-22T10:00:09.941Z
# 962            junior  54.4591851  18.4622458  2021-06-21T15:00:00.000Z
# 3632           senior   51.921253   19.145759  2021-06-17T12:00:10.039Z
#
#       remote_interview                                                 id  \
# 47                True     sperasoft-noc-technician-tech-support-engineer
# 227               True                            gaspol-sa-net-developer
# 588               True  vivid-games-s-a-junior-it-support-specialist-p...
# 592               True         dotlinkers-senior-software-engineer-krakow
# 962               True                            flowair-specjalista-erp
# 3632              True             milo-solutions-senior-web-engineer-mid
#
#                                        employment_types  \
# 47                    [{'type': 'b2b', 'salary': None}]
# 227                   [{'type': 'b2b', 'salary': None}]
# 588             [{'type': 'permanent', 'salary': None}]
# 592   [{'type': 'permanent', 'salary': {'from': 2000...
# 962   [{'type': 'permanent', 'salary': {'from': 3600...
# 3632  [{'type': 'b2b', 'salary': {'from': 16000, 'to...
#
#                                        company_logo_url  \
# 47    https://bucket.justjoin.it/offers/company_logo...
# 227   https://bucket.justjoin.it/offers/company_logo...
# 588   https://bucket.justjoin.it/offers/company_logo...
# 592   https://bucket.justjoin.it/offers/company_logo...
# 962   https://bucket.justjoin.it/offers/company_logo...
# 3632  https://bucket.justjoin.it/offers/company_logo...
#
#                                                  skills  remote
# 47    [{'name': 'Linux', 'level': 3}, {'name': 'GNU'...   False
# 227   [{'name': 'Angular', 'level': 3}, {'name': 'AS...   False
# 588   [{'name': 'VPN', 'level': 2}, {'name': 'Mac OS...   False
# 592   [{'name': 'Hadoop', 'level': 4}, {'name': 'Big...    True
# 962   [{'name': 'Oracle', 'level': 2}, {'name': 'ERP...   False
# 3632  [{'name': 'JavaScript', 'level': 4}, {'name': ...    True

# %%
# Changing the values of the country_code from NaN to "PL"
df["country_code"] = df["country_code"].fillna("PL")

# %% [markdown]
# # Add some new features

# %% [markdown]
# ## Contract type

# %%
# Custom function
def get_contract_type(data):
    return data[0]["type"]

# %%
df["contract_type"] = df["employment_types"].apply(get_contract_type)

# %%
# Browsing unique contr"act types
df["contract_type"].unique()
# Out:
# array(['b2b', 'permanent', 'mandate_contract'], dtype=object)

# %% [markdown]
# ## Price (Target)

# %%
def get_salary(data, label="from"):
    if data[0]["salary"] is not None:
        return data[0]["salary"][label]
    else:
        return data[0]["salary"]
    
def get_currency(data):
    if data[0]["salary"] is not None:
        return data[0]["salary"]["currency"]
    else:
        return None

# %%
# Get salary min
df["salary_min"] = df["employment_types"].apply(get_salary)

# Get salary max
df["salary_max"] = df["employment_types"].apply(get_salary,label="to")

# Get currency
df["currency"] = df["employment_types"].apply(get_currency)

# %% [markdown]
# ## Skills and Technology

# %% [markdown]
# ## Technology

# %%
# Get number of technology per offert
df["num_technology"] = df["skills"].apply(len)

# %%
# Custom function to get skills and level from dictionary

def get_skill(x):
    skills = []
    for num_skills in range(len(x)):
        try:
            skills.append(x[num_skills]["name"])
        except:
            continue
    return skills

def get_level(x):
    levels = []
    for num_skills in range(len(x)):
        try:
            levels.append(x[num_skills]["level"])
        except:
            continue
    return levels

# %%
df["technology"] = df["skills"].apply(get_skill)
df["levels"] = df["skills"].apply(get_level)

# %%
# Check our results
df[["technology", "levels"]]
# Out:
#                                      technology     levels
# 0                 [UX Design, UI Design, Figma]  [4, 5, 5]
# 1                [JavaScript, Postman, Cypress]  [2, 3, 3]
# 2                      [REST API, GSUITE, JIRA]  [2, 2, 3]
# 3     [Responsive Web Design, WordPress, PHP 7]  [3, 3, 3]
# 4     [Test Automation, Testing Tools, Testing]  [3, 3, 3]
# ...                                         ...        ...
# 4925             [React, GitFLow, RWD HTML CSS]  [3, 3, 3]
# 4926              [Spring, Java 8, Spring Boot]  [3, 3, 4]
# 4927                                  [Angular]        [4]
# 4928            [MySQL, React, Node.js Express]  [5, 5, 5]
# 4929                [GraphQL, MySQL, Symfony 4]  [2, 3, 4]
#
# [4930 rows x 2 columns]

# %%
# Browsing unique marker_icon => technology
technologies = df["marker_icon"].unique()

# %%
########################
# TO-DO
########################

# Create tech stack per technology
tech_stack = {}
for technology in technologies:
    frameworks = []
    technology_df = df.loc[df["marker_icon"] == technology]["technology"]
    for row in technology_df:
        frameworks.extend(row)
    tech_stack[technology] = list(set(frameworks))

# %% [markdown]
# # Results

# %%
# Show our dataframe
df.head()
# Out:
#                       title         street      city country_code  \
# 0            UI/UX Designer      Krucza 50  Warszawa           PL
# 1  Test Automation Engineer  ul. Krucza 50  Warszawa           PL
# 2     IT Support Specialist      Krucza 50  Warszawa           PL
# 3     Programista Wordpress        Centrum    Kraków           PL
# 4          Tester / Analyst      Wołoska 5  Warszawa           PL
#
#               address_text marker_icon workplace_type            company_name  \
# 0      Krucza 50, Warszawa          ux         office              ShareSpace
# 1  ul. Krucza 50, Warszawa     testing         office              ShareSpace
# 2      Krucza 50, Warszawa     support         office              ShareSpace
# 3          Centrum, Kraków         php         office                 L.GRANT
# 4      Wołoska 5, Warszawa     testing  partly_remote  Turbine Analytics S.A.
#
#                    company_url company_size  ...  \
# 0   http://www.sharespace.work          20+  ...
# 1   http://www.sharespace.work          20+  ...
# 2   http://www.sharespace.work          20+  ...
# 3      https://www.lgrant.com/           10  ...
# 4  http://turbineanalytics.com           33  ...
#
#                                     company_logo_url  \
# 0  https://bucket.justjoin.it/offers/company_logo...
# 1  https://bucket.justjoin.it/offers/company_logo...
# 2  https://bucket.justjoin.it/offers/company_logo...
# 3  https://bucket.justjoin.it/offers/company_logo...
# 4  https://bucket.justjoin.it/offers/company_logo...
#
#                                               skills remote contract_type  \
# 0  [{'name': 'UX Design', 'level': 4}, {'name': '...  False           b2b
# 1  [{'name': 'JavaScript', 'level': 2}, {'name': ...  False           b2b
# 2  [{'name': 'REST API', 'level': 2}, {'name': 'G...  False           b2b
# 3  [{'name': 'Responsive Web Design', 'level': 3}...  False     permanent
# 4  [{'name': 'Test Automation', 'level': 3}, {'na...  False           b2b
#
#    salary_min salary_max currency num_technology  \
# 0      9000.0    12000.0      pln              3
# 1     10000.0    12000.0      pln              3
# 2      6000.0     8000.0      pln              3
# 3      7000.0     9000.0      pln              3
# 4      6000.0    11000.0      pln              3
#
#                                   technology     levels
# 0              [UX Design, UI Design, Figma]  [4, 5, 5]
# 1             [JavaScript, Postman, Cypress]  [2, 3, 3]
# 2                   [REST API, GSUITE, JIRA]  [2, 2, 3]
# 3  [Responsive Web Design, WordPress, PHP 7]  [3, 3, 3]
# 4  [Test Automation, Testing Tools, Testing]  [3, 3, 3]
#
# [5 rows x 27 columns]

# %% [markdown]
# # Export dataframe to CSV

# %%
df.to_csv("../data/justjoin_offers.csv", index=False)
