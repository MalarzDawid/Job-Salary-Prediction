# %% [markdown]
# # Imports

# %%
# Import the necessary packages
import os
import requests
import pandas as pd

# %% [markdown]
# # Download data from justjoin.it API

# %% [markdown]
# Download data from justjoin.it api and save to `csv` file

# %%
request = requests.get("https://justjoin.it/api/offers")
data = request.json()

df = pd.DataFrame.from_dict(data)

# Create dir and export csv file
os.makedirs("../data", exist_ok=True)
df.to_csv("../data/justjoin_jobs.csv")

# %% [markdown]
# # Data Viewing

# %%
df.head()
# Out:
#                       title       street       city country_code  \
# 0          Tester / Analyst    Wołoska 5   Warszawa           PL
# 1  Senior Android Developer  Trzy Lipy 3     Gdańsk           PL
# 2         Android Developer  Towarowa 20  Bydgoszcz           PL
# 3      Senior iOS Developer  Towarowa 20  Bydgoszcz           PL
# 4             iOS Developer  Towarowa 20  Bydgoszcz           PL
#
#              address_text marker_icon workplace_type            company_name  \
# 0     Wołoska 5, Warszawa     testing  partly_remote  Turbine Analytics S.A.
# 1     Trzy Lipy 3, Gdańsk      mobile         remote                 itCraft
# 2  Towarowa 20, Bydgoszcz      mobile         remote                 itCraft
# 3  Towarowa 20, Bydgoszcz      mobile         remote                 itCraft
# 4  Towarowa 20, Bydgoszcz      mobile         remote                 itCraft
#
#                    company_url company_size experience_level    latitude  \
# 0  http://turbineanalytics.com           33              mid  52.1809093
# 1     https://itcraftapps.com/         >100           senior  54.3546914
# 2     https://itcraftapps.com/         >100              mid   53.125391
# 3     https://itcraftapps.com/         >100           senior  53.1253028
# 4     https://itcraftapps.com/         >100              mid   53.125391
#
#     longitude              published_at  remote_interview  \
# 0  20.9999908  2021-06-15T12:21:00.000Z              True
# 1  18.5935692  2021-06-15T11:51:00.000Z              True
# 2  18.0694589  2021-06-15T11:51:00.000Z              True
# 3  18.0695019  2021-06-15T11:51:00.000Z              True
# 4  18.0694589  2021-06-15T11:51:00.000Z              True
#
#                                                   id  \
# 0               turbine-analytics-s-a-tester-analyst
# 1  itcraft-android-developer-1a831192-468b-4c6b-a...
# 2  itcraft-android-developer-10b3040b-2e5b-4592-8...
# 3  itcraft-senior-ios-developer-dde650ec-3239-480...
# 4  itcraft-ios-developer-a715a9d6-b1fd-4f0b-aeb3-...
#
#                                     employment_types  \
# 0  [{'type': 'b2b', 'salary': {'from': 6000, 'to'...
# 1  [{'type': 'b2b', 'salary': {'from': 13500, 'to...
# 2  [{'type': 'b2b', 'salary': {'from': 7500, 'to'...
# 3  [{'type': 'b2b', 'salary': {'from': 13500, 'to...
# 4  [{'type': 'b2b', 'salary': {'from': 7500, 'to'...
#
#                                     company_logo_url  \
# 0  https://bucket.justjoin.it/offers/company_logo...
# 1  https://bucket.justjoin.it/offers/company_logo...
# 2  https://bucket.justjoin.it/offers/company_logo...
# 3  https://bucket.justjoin.it/offers/company_logo...
# 4  https://bucket.justjoin.it/offers/company_logo...
#
#                                               skills  remote
# 0  [{'name': 'Test Automation', 'level': 3}, {'na...   False
# 1  [{'name': 'English', 'level': 4}, {'name': 'An...    True
# 2  [{'name': 'Java', 'level': 3}, {'name': 'Kotli...    True
# 3  [{'name': 'English', 'level': 4}, {'name': 'iO...    True
# 4  [{'name': 'Java', 'level': 3}, {'name': 'Engli...    True

# %%
# Get info about columns type and non-null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4926 entries, 0 to 4925
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             4926 non-null   object
#  1   street            4923 non-null   object
#  2   city              4926 non-null   object
#  3   country_code      4922 non-null   object
#  4   address_text      4926 non-null   object
#  5   marker_icon       4926 non-null   object
#  6   workplace_type    4926 non-null   object
#  7   company_name      4926 non-null   object
#  8   company_url       4926 non-null   object
#  9   company_size      4926 non-null   object
#  10  experience_level  4926 non-null   object
#  11  latitude          4926 non-null   object
#  12  longitude         4926 non-null   object
#  13  published_at      4926 non-null   object
#  14  remote_interview  4926 non-null   bool
#  15  id                4926 non-null   object
#  16  employment_types  4926 non-null   object
#  17  company_logo_url  4926 non-null   object
#  18  skills            4926 non-null   object
#  19  remote            4926 non-null   bool
# dtypes: bool(2), object(18)
# memory usage: 702.5+ KB

# %% [markdown]
# # Null values

# %%
# Check null values
df.isnull().sum()
# Out:
# title               0
# street              3
# city                0
# country_code        4
# address_text        0
# marker_icon         0
# workplace_type      0
# company_name        0
# company_url         0
# company_size        0
# experience_level    0
# latitude            0
# longitude           0
# published_at        0
# remote_interview    0
# id                  0
# employment_types    0
# company_logo_url    0
# skills              0
# remote              0
# dtype: int64

# %%
# Find null values in country_code column
df.loc[df['country_code'].isnull()]
# Out:
#                                          title               street  \
# 1127                  Senior Software Engineer               Kraków
# 3849                 Senior Web Engineer / Mid  ul. Nałęczowska 36C
# 4240                           Specjalista ERP    Chwaszczyńska 135
# 4377  Junior IT Support Specialist - part time         Ogińskiego 2
#
#            city country_code                 address_text marker_icon  \
# 1127     Kraków         None               Kraków, Kraków        java
# 3849     Lublin         None  ul. Nałęczowska 36C, Lublin      python
# 4240     Gdynia         None    Chwaszczyńska 135, Gdynia         erp
# 4377  Bydgoszcz         None      Ogińskiego 2, Bydgoszcz     support
#
#      workplace_type       company_name  \
# 1127         remote         dotLinkers
# 3849         remote     Milo Solutions
# 4240         office            FLOWAIR
# 4377  partly_remote  Vivid Games S. A.
#
#                                             company_url company_size  \
# 1127                              http://dotlinkers.pl/           17
# 3849  https://www.milosolutions.com?utm_source=JustJ...        50-60
# 4240                              http://www.flowair.pl      100-200
# 4377                            https://vividgames.com/           70
#
#      experience_level    latitude   longitude              published_at  \
# 1127           senior   51.921253   19.145759  2021-06-14T09:21:00.000Z
# 3849           senior   51.921253   19.145759  2021-06-09T11:00:09.995Z
# 4240           junior  54.4591851  18.4622458  2021-06-08T09:00:00.000Z
# 4377           junior   51.921253   19.145759  2021-06-07T09:34:00.000Z
#
#       remote_interview                                                 id  \
# 1127              True         dotlinkers-senior-software-engineer-krakow
# 3849              True             milo-solutions-senior-web-engineer-mid
# 4240              True                            flowair-specjalista-erp
# 4377              True  vivid-games-s-a-junior-it-support-specialist-p...
#
#                                        employment_types  \
# 1127  [{'type': 'permanent', 'salary': {'from': 2000...
# 3849  [{'type': 'b2b', 'salary': {'from': 9100, 'to'...
# 4240            [{'type': 'permanent', 'salary': None}]
# 4377            [{'type': 'permanent', 'salary': None}]
#
#                                        company_logo_url  \
# 1127  https://bucket.justjoin.it/offers/company_logo...
# 3849  https://bucket.justjoin.it/offers/company_logo...
# 4240  https://bucket.justjoin.it/offers/company_logo...
# 4377  https://bucket.justjoin.it/offers/company_logo...
#
#                                                  skills  remote
# 1127  [{'name': 'Hadoop', 'level': 4}, {'name': 'Big...    True
# 3849  [{'name': 'JavaScript', 'level': 4}, {'name': ...    True
# 4240  [{'name': 'Oracle', 'level': 3}, {'name': 'ERP...   False
# 4377  [{'name': 'VPN', 'level': 2}, {'name': 'Mac OS...   False

# %%
# Changing the values of the country_code from NaN to "PL"
df['country_code'] = df['country_code'].fillna('PL', inplace=True)

# %% [markdown]
# # Add some new features

# %% [markdown]
# ## Contract type

# %%
# Custom function
def get_contract_type(data):
    return data[0]['type']

# %%
df['contract_type'] = df['employment_types'].apply(get_contract_type)

# %%
# Browsing unique contr"act types
df['contract_type'].unique()
# Out:
# array(['b2b', 'mandate_contract', 'permanent'], dtype=object)

# %% [markdown]
# ## Price (Target)

# %%
def get_salary(data, label="from"):
    if data[0]['salary'] is not None:
        return data[0]['salary'][label]
    else:
        return data[0]['salary']
    
def get_currency(data):
    if data[0]['salary'] is not None:
        return data[0]['salary']['currency']
    else:
        return None

# %%
# Get salary min
df['salary_min'] = df['employment_types'].apply(get_salary)

# Get salary max
df['salary_max'] = df['employment_types'].apply(get_salary,label="to")

# Get currency
df['currency'] = df['employment_types'].apply(get_currency)

# %% [markdown]
# ## Skills and Technology

# %% [markdown]
# ## Technology

# %%
# Get number of technology per offert
df['num_technology'] = df['skills'].apply(len)

# %%
# Custom function to get skills and level from dictionary

def get_skill(x):
    skills = []
    for num_skills in range(len(x)):
        try:
            skills.append(x[num_skills]['name'])
        except:
            continue
    return skills

def get_level(x):
    levels = []
    for num_skills in range(len(x)):
        try:
            levels.append(x[num_skills]['level'])
        except:
            continue
    return levels

# %%
df['technology'] = df['skills'].apply(get_skill)
df['levels'] = df['skills'].apply(get_level)

# %%
# Check our results
df[['technology', 'levels']]
# Out:
#                                      technology     levels
# 0     [Test Automation, Testing Tools, Testing]  [3, 3, 3]
# 1                    [English, Android, Kotlin]  [4, 5, 5]
# 2                       [Java, Kotlin, Android]  [3, 3, 3]
# 3                [English, iOS Platform, Swift]  [4, 4, 4]
# 4                       [Java, English, Kotlin]  [3, 3, 3]
# ...                                         ...        ...
# 4921             [React, GitFLow, RWD HTML CSS]  [3, 3, 3]
# 4922              [Spring, Java 8, Spring Boot]  [3, 3, 4]
# 4923                                  [Angular]        [4]
# 4924            [MySQL, React, Node.js Express]  [5, 5, 5]
# 4925                [GraphQL, MySQL, Symfony 4]  [2, 3, 4]
#
# [4926 rows x 2 columns]

# %%
# Browsing unique marker_icon => technology
technologies = df['marker_icon'].unique()

# %%
########################
# TO-DO
########################

# Create tech stack per technology
tech_stack = {}
for technology in technologies:
    frameworks = []
    technology_df = df.loc[df['marker_icon'] == technology]['technology']
    for row in technology_df:
        frameworks.extend(row)
    tech_stack[technology] = list(set(frameworks))

# %% [markdown]
# # Results

# %%
# Show our dataframe
df.head()
# Out:
#                       title       street       city country_code  \
# 0          Tester / Analyst    Wołoska 5   Warszawa         None
# 1  Senior Android Developer  Trzy Lipy 3     Gdańsk         None
# 2         Android Developer  Towarowa 20  Bydgoszcz         None
# 3      Senior iOS Developer  Towarowa 20  Bydgoszcz         None
# 4             iOS Developer  Towarowa 20  Bydgoszcz         None
#
#              address_text marker_icon workplace_type            company_name  \
# 0     Wołoska 5, Warszawa     testing  partly_remote  Turbine Analytics S.A.
# 1     Trzy Lipy 3, Gdańsk      mobile         remote                 itCraft
# 2  Towarowa 20, Bydgoszcz      mobile         remote                 itCraft
# 3  Towarowa 20, Bydgoszcz      mobile         remote                 itCraft
# 4  Towarowa 20, Bydgoszcz      mobile         remote                 itCraft
#
#                    company_url company_size  ...  \
# 0  http://turbineanalytics.com           33  ...
# 1     https://itcraftapps.com/         >100  ...
# 2     https://itcraftapps.com/         >100  ...
# 3     https://itcraftapps.com/         >100  ...
# 4     https://itcraftapps.com/         >100  ...
#
#                                     company_logo_url  \
# 0  https://bucket.justjoin.it/offers/company_logo...
# 1  https://bucket.justjoin.it/offers/company_logo...
# 2  https://bucket.justjoin.it/offers/company_logo...
# 3  https://bucket.justjoin.it/offers/company_logo...
# 4  https://bucket.justjoin.it/offers/company_logo...
#
#                                               skills remote contract_type  \
# 0  [{'name': 'Test Automation', 'level': 3}, {'na...  False           b2b
# 1  [{'name': 'English', 'level': 4}, {'name': 'An...   True           b2b
# 2  [{'name': 'Java', 'level': 3}, {'name': 'Kotli...   True           b2b
# 3  [{'name': 'English', 'level': 4}, {'name': 'iO...   True           b2b
# 4  [{'name': 'Java', 'level': 3}, {'name': 'Engli...   True           b2b
#
#    salary_min salary_max currency num_technology  \
# 0      6000.0    11000.0      pln              3
# 1     13500.0    19000.0      pln              3
# 2      7500.0    13000.0      pln              3
# 3     13500.0    19000.0      pln              3
# 4      7500.0    13000.0      pln              3
#
#                                   technology     levels
# 0  [Test Automation, Testing Tools, Testing]  [3, 3, 3]
# 1                 [English, Android, Kotlin]  [4, 5, 5]
# 2                    [Java, Kotlin, Android]  [3, 3, 3]
# 3             [English, iOS Platform, Swift]  [4, 4, 4]
# 4                    [Java, English, Kotlin]  [3, 3, 3]
#
# [5 rows x 27 columns]

# %% [markdown]
# # Export dataframe to CSV

# %%
df.to_csv("../data/justjoin_offers.csv", index=False)
