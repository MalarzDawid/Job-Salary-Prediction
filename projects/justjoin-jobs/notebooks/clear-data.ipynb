# %% [markdown]
# # Imports

# %%
import ast
import pandas as pd

# %% [markdown]
# # Read file

# %%
df = pd.read_csv("../data/justjoin_jobs.csv", index_col=0)

# %% [markdown]
# # Basic informations

# %%
df.head()
# Out:
#                                       title                 street      city  \
# 0  Lead Full-Stack Developer (React + Java)                Centrum  Warszawa
# 1                             Data Engineer         Porcelanowa, 8  Katowice
# 2                           DevOps Engineer         Porcelanowa, 8  Katowice
# 3               Senior Jakarta EE Developer  ul. Bukowińska 24 d/7  Warszawa
# 4                        Senior UX Designer                Pawia 9    Kraków
#
#   country_code                     address_text marker_icon workplace_type  \
# 0           PL                Centrum, Warszawa  javascript         remote
# 1           PL         Porcelanowa, 8, Katowice   analytics         office
# 2           PL         Porcelanowa, 8, Katowice      devops         office
# 3           PL  ul. Bukowińska 24 d/7, Warszawa        java         remote
# 4           PL                  Pawia 9, Kraków          ux         remote
#
#   company_name                 company_url company_size experience_level  \
# 0       Efisco         https://efisco.net/        10-35           senior
# 1          STS  https://stsgaminggroup.com         1500              mid
# 2          STS  https://stsgaminggroup.com         1500              mid
# 3   super devs      https://superdevs.com/           50           senior
# 4      Netguru          http://netguru.com          600           senior
#
#     latitude  longitude              published_at  remote_interview  \
# 0  52.229375  21.013196  2021-02-26T19:52:00.000Z              True
# 1  50.264892  19.023782  2021-02-26T19:11:50.507Z              True
# 2  50.251405  19.050230  2021-02-26T19:03:39.277Z              True
# 3  52.183231  21.025169  2021-02-26T19:00:07.492Z              True
# 4  50.069879  19.946371  2021-02-26T19:00:07.492Z             False
#
#                                             id  \
# 0  efisco-lead-full-stack-developer-react-java
# 1                            sts-data-engineer
# 2                          sts-devops-engineer
# 3       super-devs-senior-jakarta-ee-developer
# 4                   netguru-senior-ux-designer
#
#                                     employment_types  \
# 0  [{'type': 'b2b', 'salary': {'from': 4000, 'to'...
# 1            [{'type': 'permanent', 'salary': None}]
# 2            [{'type': 'permanent', 'salary': None}]
# 3  [{'type': 'b2b', 'salary': {'from': 18000, 'to...
# 4                  [{'type': 'b2b', 'salary': None}]
#
#                                     company_logo_url  \
# 0  https://bucket.justjoin.it/offers/company_logo...
# 1  https://bucket.justjoin.it/offers/company_logo...
# 2  https://bucket.justjoin.it/offers/company_logo...
# 3  https://bucket.justjoin.it/offers/company_logo...
# 4  https://bucket.justjoin.it/offers/company_logo...
#
#                                               skills  remote
# 0  [{'name': 'Java', 'level': 4}, {'name': 'SQL',...    True
# 1  [{'name': 'MySQL', 'level': 3}, {'name': 'Apac...   False
# 2  [{'name': 'Bash', 'level': 3}, {'name': 'Pytho...   False
# 3  [{'name': 'Hibernate', 'level': 5}, {'name': '...    True
# 4                       [{'name': 'UX', 'level': 4}]    True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3745 entries, 0 to 3744
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             3745 non-null   object
#  1   street            3728 non-null   object
#  2   city              3745 non-null   object
#  3   country_code      3740 non-null   object
#  4   address_text      3745 non-null   object
#  5   marker_icon       3745 non-null   object
#  6   workplace_type    3745 non-null   object
#  7   company_name      3745 non-null   object
#  8   company_url       3745 non-null   object
#  9   company_size      3745 non-null   object
#  10  experience_level  3745 non-null   object
#  11  latitude          3745 non-null   float64
#  12  longitude         3745 non-null   float64
#  13  published_at      3745 non-null   object
#  14  remote_interview  3745 non-null   bool
#  15  id                3745 non-null   object
#  16  employment_types  3745 non-null   object
#  17  company_logo_url  3745 non-null   object
#  18  skills            3745 non-null   object
#  19  remote            3745 non-null   bool
# dtypes: bool(2), float64(2), object(16)
# memory usage: 563.2+ KB

# %% [markdown]
# # Null values

# %%
df.isnull().sum()
# Out:
# title                0
# street              17
# city                 0
# country_code         5
# address_text         0
# marker_icon          0
# workplace_type       0
# company_name         0
# company_url          0
# company_size         0
# experience_level     0
# latitude             0
# longitude            0
# published_at         0
# remote_interview     0
# id                   0
# employment_types     0
# company_logo_url     0
# skills               0
# remote               0
# dtype: int64

# %%
df.loc[df['country_code'].isnull() == True]
# Out:
#                          title            street      city country_code  \
# 607             Data Architect           Centrum  Warszawa          NaN
# 1008     Senior Data Scientist     Marynarska 12  Warszawa          NaN
# 2057           DevOps Engineer        Wołoska 24  Warszawa          NaN
# 2569  Senior Shopify Developer         Wołoska 9  Warszawa          NaN
# 3111        Frontend Developer  Nowy Świat 54/56  Warszawa          NaN
#
#                     address_text marker_icon workplace_type  \
# 607            Centrum, Warszawa        data         remote
# 1008     Marynarska 12, Warszawa        data         remote
# 2057        Wołoska 24, Warszawa      devops         remote
# 2569         Wołoska 9, Warszawa        html         remote
# 3111  Nowy Świat 54/56, Warszawa  javascript  partly_remote
#
#                   company_name                       company_url company_size  \
# 607           DCV Technologies  http://www.dcvtechnologies.co.uk      20 - 50
# 1008      T-Mobile Polska S.A.          https://www.t-mobile.pl/         4500
# 2057  Inetum Polska Sp. z o.o.            https://gfieast.com/pl      200-450
# 2569        Relyon IT Services              https://rits.center/          300
# 3111                  Nebucode         https://www.nebucode.com/        11-50
#
#      experience_level   latitude  longitude              published_at  \
# 607            senior  52.229375  21.013196  2021-02-26T09:00:09.605Z
# 1008           senior  51.921253  19.145759  2021-02-25T12:08:00.000Z
# 2057              mid  51.921253  19.145759  2021-02-23T13:05:00.000Z
# 2569           senior  51.921253  19.145759  2021-02-22T12:35:00.000Z
# 3111              mid  52.235090  21.018839  2021-02-20T08:00:08.967Z
#
#       remote_interview                                                 id  \
# 607               True           dcv-technologies-data-architect-warszawa
# 1008             False  t-mobile-polska-s-a-senior-data-scientist-ad42...
# 2057              True       gfi-poland-sp-z-o-o-devops-engineer-warszawa
# 2569              True        relyon-it-services-senior-shopify-developer
# 3111              True                        nebucode-frontend-developer
#
#                                        employment_types  \
# 607   [{'type': 'b2b', 'salary': {'from': 18000, 'to...
# 1008            [{'type': 'permanent', 'salary': None}]
# 2057  [{'type': 'permanent', 'salary': None}, {'type...
# 2569  [{'type': 'b2b', 'salary': {'from': 15000, 'to...
# 3111  [{'type': 'mandate_contract', 'salary': {'from...
#
#                                        company_logo_url  \
# 607   https://bucket.justjoin.it/offers/company_logo...
# 1008  https://bucket.justjoin.it/offers/company_logo...
# 2057  https://bucket.justjoin.it/offers/company_logo...
# 2569  https://bucket.justjoin.it/offers/company_logo...
# 3111  https://bucket.justjoin.it/offers/company_logo...
#
#                                                  skills  remote
# 607   [{'name': 'Data Integration', 'level': 4}, {'n...    True
# 1008  [{'name': 'SQL', 'level': 4}, {'name': 'Data S...    True
# 2057  [{'name': 'CI / CD', 'level': 4}, {'name': 'Ja...    True
# 2569  [{'name': 'HTML', 'level': 4}, {'name': 'CSS',...    True
# 3111  [{'name': 'JS', 'level': 4}, {'name': 'CSS', '...   False

# %%
df['country_code'] = df['country_code'].fillna('PL')

# %%
df.head()
# Out:
#                                       title                 street      city  \
# 0  Lead Full-Stack Developer (React + Java)                Centrum  Warszawa
# 1                             Data Engineer         Porcelanowa, 8  Katowice
# 2                           DevOps Engineer         Porcelanowa, 8  Katowice
# 3               Senior Jakarta EE Developer  ul. Bukowińska 24 d/7  Warszawa
# 4                        Senior UX Designer                Pawia 9    Kraków
#
#   country_code                     address_text marker_icon workplace_type  \
# 0           PL                Centrum, Warszawa  javascript         remote
# 1           PL         Porcelanowa, 8, Katowice   analytics         office
# 2           PL         Porcelanowa, 8, Katowice      devops         office
# 3           PL  ul. Bukowińska 24 d/7, Warszawa        java         remote
# 4           PL                  Pawia 9, Kraków          ux         remote
#
#   company_name                 company_url company_size experience_level  \
# 0       Efisco         https://efisco.net/        10-35           senior
# 1          STS  https://stsgaminggroup.com         1500              mid
# 2          STS  https://stsgaminggroup.com         1500              mid
# 3   super devs      https://superdevs.com/           50           senior
# 4      Netguru          http://netguru.com          600           senior
#
#     latitude  longitude              published_at  remote_interview  \
# 0  52.229375  21.013196  2021-02-26T19:52:00.000Z              True
# 1  50.264892  19.023782  2021-02-26T19:11:50.507Z              True
# 2  50.251405  19.050230  2021-02-26T19:03:39.277Z              True
# 3  52.183231  21.025169  2021-02-26T19:00:07.492Z              True
# 4  50.069879  19.946371  2021-02-26T19:00:07.492Z             False
#
#                                             id  \
# 0  efisco-lead-full-stack-developer-react-java
# 1                            sts-data-engineer
# 2                          sts-devops-engineer
# 3       super-devs-senior-jakarta-ee-developer
# 4                   netguru-senior-ux-designer
#
#                                     employment_types  \
# 0  [{'type': 'b2b', 'salary': {'from': 4000, 'to'...
# 1            [{'type': 'permanent', 'salary': None}]
# 2            [{'type': 'permanent', 'salary': None}]
# 3  [{'type': 'b2b', 'salary': {'from': 18000, 'to...
# 4                  [{'type': 'b2b', 'salary': None}]
#
#                                     company_logo_url  \
# 0  https://bucket.justjoin.it/offers/company_logo...
# 1  https://bucket.justjoin.it/offers/company_logo...
# 2  https://bucket.justjoin.it/offers/company_logo...
# 3  https://bucket.justjoin.it/offers/company_logo...
# 4  https://bucket.justjoin.it/offers/company_logo...
#
#                                               skills  remote
# 0  [{'name': 'Java', 'level': 4}, {'name': 'SQL',...    True
# 1  [{'name': 'MySQL', 'level': 3}, {'name': 'Apac...   False
# 2  [{'name': 'Bash', 'level': 3}, {'name': 'Pytho...   False
# 3  [{'name': 'Hibernate', 'level': 5}, {'name': '...    True
# 4                       [{'name': 'UX', 'level': 4}]    True

# %% [markdown]
# # Add some new features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3745 entries, 0 to 3744
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             3745 non-null   object
#  1   street            3728 non-null   object
#  2   city              3745 non-null   object
#  3   country_code      3745 non-null   object
#  4   address_text      3745 non-null   object
#  5   marker_icon       3745 non-null   object
#  6   workplace_type    3745 non-null   object
#  7   company_name      3745 non-null   object
#  8   company_url       3745 non-null   object
#  9   company_size      3745 non-null   object
#  10  experience_level  3745 non-null   object
#  11  latitude          3745 non-null   float64
#  12  longitude         3745 non-null   float64
#  13  published_at      3745 non-null   object
#  14  remote_interview  3745 non-null   bool
#  15  id                3745 non-null   object
#  16  employment_types  3745 non-null   object
#  17  company_logo_url  3745 non-null   object
#  18  skills            3745 non-null   object
#  19  remote            3745 non-null   bool
# dtypes: bool(2), float64(2), object(16)
# memory usage: 563.2+ KB

# %%
# df['employment_types'] = df['employment_types'].apply(lambda x: eval(x.strip('[]')))
df['skills'] = df['skills'].apply(lambda x: eval(x.strip('[]')))

# %%
df.head()
# Out:
#                                       title                 street      city  \
# 0  Lead Full-Stack Developer (React + Java)                Centrum  Warszawa
# 1                             Data Engineer         Porcelanowa, 8  Katowice
# 2                           DevOps Engineer         Porcelanowa, 8  Katowice
# 3               Senior Jakarta EE Developer  ul. Bukowińska 24 d/7  Warszawa
# 4                        Senior UX Designer                Pawia 9    Kraków
#
#   country_code                     address_text marker_icon workplace_type  \
# 0           PL                Centrum, Warszawa  javascript         remote
# 1           PL         Porcelanowa, 8, Katowice   analytics         office
# 2           PL         Porcelanowa, 8, Katowice      devops         office
# 3           PL  ul. Bukowińska 24 d/7, Warszawa        java         remote
# 4           PL                  Pawia 9, Kraków          ux         remote
#
#   company_name                 company_url company_size experience_level  \
# 0       Efisco         https://efisco.net/        10-35           senior
# 1          STS  https://stsgaminggroup.com         1500              mid
# 2          STS  https://stsgaminggroup.com         1500              mid
# 3   super devs      https://superdevs.com/           50           senior
# 4      Netguru          http://netguru.com          600           senior
#
#     latitude  longitude              published_at  remote_interview  \
# 0  52.229375  21.013196  2021-02-26T19:52:00.000Z              True
# 1  50.264892  19.023782  2021-02-26T19:11:50.507Z              True
# 2  50.251405  19.050230  2021-02-26T19:03:39.277Z              True
# 3  52.183231  21.025169  2021-02-26T19:00:07.492Z              True
# 4  50.069879  19.946371  2021-02-26T19:00:07.492Z             False
#
#                                             id  \
# 0  efisco-lead-full-stack-developer-react-java
# 1                            sts-data-engineer
# 2                          sts-devops-engineer
# 3       super-devs-senior-jakarta-ee-developer
# 4                   netguru-senior-ux-designer
#
#                                     employment_types  \
# 0  [{'type': 'b2b', 'salary': {'from': 4000, 'to'...
# 1            [{'type': 'permanent', 'salary': None}]
# 2            [{'type': 'permanent', 'salary': None}]
# 3  [{'type': 'b2b', 'salary': {'from': 18000, 'to...
# 4                  [{'type': 'b2b', 'salary': None}]
#
#                                     company_logo_url  \
# 0  https://bucket.justjoin.it/offers/company_logo...
# 1  https://bucket.justjoin.it/offers/company_logo...
# 2  https://bucket.justjoin.it/offers/company_logo...
# 3  https://bucket.justjoin.it/offers/company_logo...
# 4  https://bucket.justjoin.it/offers/company_logo...
#
#                                               skills  remote
# 0  ({'name': 'Java', 'level': 4}, {'name': 'SQL',...    True
# 1  ({'name': 'MySQL', 'level': 3}, {'name': 'Apac...   False
# 2  ({'name': 'Bash', 'level': 3}, {'name': 'Pytho...   False
# 3  ({'name': 'Hibernate', 'level': 5}, {'name': '...    True
# 4                         {'name': 'UX', 'level': 4}    True

# %% [markdown]
# ## Contract type

# %%
# Switch string to arary
def to_array(data):
    data = ast.literal_eval(data)
    return data

df['employment_types'] = df['employment_types'].apply(lambda x: to_array(x))

# %%
def get_contract_type(data):
    return data[0]['type']

# %%
df['contract_type'] = df['employment_types'].apply(lambda x: get_contract_type(x))

# %%
df['contract_type'].unique()
# Out:
# array(['b2b', 'permanent', 'mandate_contract'], dtype=object)

# %%
df.head()
# Out:
#                                       title                 street      city  \
# 0  Lead Full-Stack Developer (React + Java)                Centrum  Warszawa
# 1                             Data Engineer         Porcelanowa, 8  Katowice
# 2                           DevOps Engineer         Porcelanowa, 8  Katowice
# 3               Senior Jakarta EE Developer  ul. Bukowińska 24 d/7  Warszawa
# 4                        Senior UX Designer                Pawia 9    Kraków
#
#   country_code                     address_text marker_icon workplace_type  \
# 0           PL                Centrum, Warszawa  javascript         remote
# 1           PL         Porcelanowa, 8, Katowice   analytics         office
# 2           PL         Porcelanowa, 8, Katowice      devops         office
# 3           PL  ul. Bukowińska 24 d/7, Warszawa        java         remote
# 4           PL                  Pawia 9, Kraków          ux         remote
#
#   company_name                 company_url company_size  ...   latitude  \
# 0       Efisco         https://efisco.net/        10-35  ...  52.229375
# 1          STS  https://stsgaminggroup.com         1500  ...  50.264892
# 2          STS  https://stsgaminggroup.com         1500  ...  50.251405
# 3   super devs      https://superdevs.com/           50  ...  52.183231
# 4      Netguru          http://netguru.com          600  ...  50.069879
#
#    longitude              published_at remote_interview  \
# 0  21.013196  2021-02-26T19:52:00.000Z             True
# 1  19.023782  2021-02-26T19:11:50.507Z             True
# 2  19.050230  2021-02-26T19:03:39.277Z             True
# 3  21.025169  2021-02-26T19:00:07.492Z             True
# 4  19.946371  2021-02-26T19:00:07.492Z            False
#
#                                             id  \
# 0  efisco-lead-full-stack-developer-react-java
# 1                            sts-data-engineer
# 2                          sts-devops-engineer
# 3       super-devs-senior-jakarta-ee-developer
# 4                   netguru-senior-ux-designer
#
#                                     employment_types  \
# 0  [{'type': 'b2b', 'salary': {'from': 4000, 'to'...
# 1            [{'type': 'permanent', 'salary': None}]
# 2            [{'type': 'permanent', 'salary': None}]
# 3  [{'type': 'b2b', 'salary': {'from': 18000, 'to...
# 4                  [{'type': 'b2b', 'salary': None}]
#
#                                     company_logo_url  \
# 0  https://bucket.justjoin.it/offers/company_logo...
# 1  https://bucket.justjoin.it/offers/company_logo...
# 2  https://bucket.justjoin.it/offers/company_logo...
# 3  https://bucket.justjoin.it/offers/company_logo...
# 4  https://bucket.justjoin.it/offers/company_logo...
#
#                                               skills remote  contract_type
# 0  ({'name': 'Java', 'level': 4}, {'name': 'SQL',...   True            b2b
# 1  ({'name': 'MySQL', 'level': 3}, {'name': 'Apac...  False      permanent
# 2  ({'name': 'Bash', 'level': 3}, {'name': 'Pytho...  False      permanent
# 3  ({'name': 'Hibernate', 'level': 5}, {'name': '...   True            b2b
# 4                         {'name': 'UX', 'level': 4}   True            b2b
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Price

# %%
df['employment_types'][0]
# Out:
# [{'type': 'b2b', 'salary': {'from': 4000, 'to': 8000, 'currency': 'usd'}},
#  {'type': 'permanent',
#   'salary': {'from': 3500, 'to': 5000, 'currency': 'usd'}}]

# %%
def get_salary(data, label="from"):
    if data[0]['salary'] is not None:
        return data[0]['salary'][label]
    else:
        return data[0]['salary']
    
def get_currency(data):
    if data[0]['salary'] is not None:
        return data[0]['salary']['currency']
    else:
        return None

# %%
df['salary_min'] = df['employment_types'].apply(lambda x: get_salary(x))
df['salary_max'] = df['employment_types'].apply(lambda x: get_salary(x, label="to"))
df['currency'] = df['employment_types'].apply(lambda x: get_currency(x))

# %% [markdown]
# ## Skills and Technology

# %%
df['skills'] = df['skills'].apply(lambda x: list(x))

# %%
def get_skill(x):
    skills = []
    for num_skills in range(len(x)):
        try:
            skills.append(x[num_skills]['name'])
        except:
            continue
    return skills

def get_level(x):
    levels = []
    for num_skills in range(len(x)):
        try:
            levels.append(x[num_skills]['level'])
        except:
            continue
    return levels

# %%
df['technology'] = df['skills'].apply(lambda x: get_skill(x))
df['levels'] = df['skills'].apply(lambda x: get_level(x))

# %%
df.tail()
# Out:
#                                title                street       city  \
# 3740                 DevOps Engineer       Dąbrowskiego 77     Poznań
# 3741                 Programista PHP                 Wendy     Gdynia
# 3742                 DevOps/SysAdmin             Ułańska 1     Poznań
# 3743  Unified Communication Engineer               Centrum   Warszawa
# 3744         Ruby on Rails Developer  Otto Mønsteds Gade 5  København
#
#      country_code                     address_text marker_icon workplace_type  \
# 3740           PL          Dąbrowskiego 77, Poznań      devops  partly_remote
# 3741           PL                    Wendy, Gdynia         php         remote
# 3742           PL                Ułańska 1, Poznań      devops         office
# 3743           PL                Centrum, Warszawa       other  partly_remote
# 3744           DK  Otto Mønsteds Gade 5, København        ruby         remote
#
#         company_name               company_url company_size  ...  \
# 3740         <exioo>      http://www.exioo.com         2-10  ...
# 3741  Balticon S. A.  https://www.balticon.pl/         300+  ...
# 3742              GH      http://gamerhash.com        10-20  ...
# 3743           ITCPW      http://itcpw.com.pl/         7-10  ...
# 3744         Tjekvik        http://tjekvik.com           12  ...
#
#                                        employment_types  \
# 3740  [{'type': 'b2b', 'salary': {'from': 8000, 'to'...
# 3741            [{'type': 'permanent', 'salary': None}]
# 3742  [{'type': 'b2b', 'salary': {'from': 8000, 'to'...
# 3743  [{'type': 'b2b', 'salary': {'from': 13000, 'to...
# 3744  [{'type': 'b2b', 'salary': {'from': 3000, 'to'...
#
#                                        company_logo_url  \
# 3740  https://bucket.justjoin.it/offers/company_logo...
# 3741  https://bucket.justjoin.it/offers/company_logo...
# 3742  https://bucket.justjoin.it/offers/company_logo...
# 3743  https://bucket.justjoin.it/offers/company_logo...
# 3744  https://bucket.justjoin.it/offers/company_logo...
#
#                                                  skills remote  contract_type  \
# 3740  [{'name': 'AWS', 'level': 3}, {'name': 'Linux'...  False            b2b
# 3741                                      [name, level]   True      permanent
# 3742  [{'name': 'TCP', 'level': 3}, {'name': 'Cloudf...  False            b2b
# 3743  [{'name': 'ms teams', 'level': 4}, {'name': 'S...  False            b2b
# 3744  [{'name': 'CSS', 'level': 1}, {'name': 'JavaSc...   True            b2b
#
#      salary_min salary_max currency                                technology  \
# 3740     8000.0    16000.0      pln                      [AWS, Linux, DevOps]
# 3741        NaN        NaN     None                                        []
# 3742     8000.0    14000.0      pln                  [TCP, Cloudflare, MySQL]
# 3743    13000.0    17000.0      pln  [ms teams, Skype for Business, Exchange]
# 3744     3000.0     4000.0      eur          [CSS, JavaScript, Ruby on Rails]
#
#          levels
# 3740  [3, 3, 3]
# 3741         []
# 3742  [3, 3, 4]
# 3743  [4, 4, 4]
# 3744  [1, 1, 3]
#
# [5 rows x 26 columns]

# %% [markdown]
# # Drop columns

# %%
df.columns
# Out:
# Index(['title', 'street', 'city', 'country_code', 'address_text',
#        'marker_icon', 'workplace_type', 'company_name', 'company_url',
#        'company_size', 'experience_level', 'latitude', 'longitude',
#        'published_at', 'remote_interview', 'id', 'employment_types',
#        'company_logo_url', 'skills', 'remote', 'contract_type', 'salary_min',
#        'salary_max', 'currency', 'technology', 'levels'],
#       dtype='object')

# %%
columns_to_drop = ['street', 'address_text', 'company_url', 'id', 'company_logo_url', 'employment_types', 'skills']

# %%
df = df.drop(labels=columns_to_drop, axis=1)

# %%
df.head()
# Out:
#                                       title      city country_code  \
# 0  Lead Full-Stack Developer (React + Java)  Warszawa           PL
# 1                             Data Engineer  Katowice           PL
# 2                           DevOps Engineer  Katowice           PL
# 3               Senior Jakarta EE Developer  Warszawa           PL
# 4                        Senior UX Designer    Kraków           PL
#
#   marker_icon workplace_type company_name company_size experience_level  \
# 0  javascript         remote       Efisco        10-35           senior
# 1   analytics         office          STS         1500              mid
# 2      devops         office          STS         1500              mid
# 3        java         remote   super devs           50           senior
# 4          ux         remote      Netguru          600           senior
#
#     latitude  longitude              published_at  remote_interview  remote  \
# 0  52.229375  21.013196  2021-02-26T19:52:00.000Z              True    True
# 1  50.264892  19.023782  2021-02-26T19:11:50.507Z              True   False
# 2  50.251405  19.050230  2021-02-26T19:03:39.277Z              True   False
# 3  52.183231  21.025169  2021-02-26T19:00:07.492Z              True    True
# 4  50.069879  19.946371  2021-02-26T19:00:07.492Z             False    True
#
#   contract_type  salary_min  salary_max currency  \
# 0           b2b      4000.0      8000.0      usd
# 1     permanent         NaN         NaN     None
# 2     permanent         NaN         NaN     None
# 3           b2b     18000.0     24000.0      pln
# 4           b2b         NaN         NaN     None
#
#                         technology     levels
# 0               [Java, SQL, React]  [4, 5, 5]
# 1    [MySQL, Apache Kafka, Python]  [3, 3, 4]
# 2   [Bash, Python, Linux (Debian)]  [3, 3, 4]
# 3  [Hibernate, Jakarta EE, Polish]  [5, 5, 5]
# 4                               []         []

# %% [markdown]
# # Export new dataset

# %%
df.to_csv("../data/clear_data.csv", index=False)
