# %% [markdown]
# # Imports

# %%
import ast
import requests
import pandas as pd

# %% [markdown]
# # Download data from justjoin.it API

# %%
request = requests.get("https://justjoin.it/api/offers")
data = request.json()

df = pd.DataFrame.from_dict(data)
df.to_csv("../data/justjoin_jobs.csv")

# %% [markdown]
# # Read file

# %%
df.head()
# Out:
#                                      title                    street  \
# 0  Fullstack Dev. - Swedish dating startup             Marszałkowska
# 1                  Senior Storage Engineer                  Basztowa
# 2                        Splunk Consultant                  Basztowa
# 3                 Senior Software Engineer  Poznań, ul. Piłsudskiego
# 4              Junior Analyst: Anti-Piracy  Poznań, ul. Piłsudskiego
#
#        city country_code                       address_text marker_icon  \
# 0  Warszawa           PL            Marszałkowska, Warszawa  javascript
# 1    Kraków           PL                   Basztowa, Kraków       other
# 2    Kraków           PL                   Basztowa, Kraków    security
# 3   Wrocław           PL  Poznań, ul. Piłsudskiego, Wrocław      devops
# 4   Wrocław           PL  Poznań, ul. Piłsudskiego, Wrocław    security
#
#   workplace_type        company_name                 company_url company_size  \
# 0         remote              Relate  https://www.relate-app.com         2-10
# 1  partly_remote  ECS Resource Group  https://theecsgroup.co.uk/      10,000+
# 2  partly_remote  ECS Resource Group  https://theecsgroup.co.uk/      10,000+
# 3  partly_remote              Irdeto       http://www.irdeto.com         1000
# 4  partly_remote              Irdeto       http://www.irdeto.com         1000
#
#   experience_level    latitude   longitude              published_at  \
# 0              mid   52.228181  21.0125682  2021-03-23T12:05:00.000Z
# 1              mid   50.066114  19.9406042  2021-03-23T12:04:00.000Z
# 2           senior   50.066114  19.9406042  2021-03-23T12:04:00.000Z
# 3           senior  51.0997775  17.0347608  2021-03-23T11:42:00.000Z
# 4           junior  51.0997775  17.0347608  2021-03-23T11:42:00.000Z
#
#    remote_interview                                           id  \
# 0             False  relate-fullstack-developer-and-head-of-data
# 1              True   ecs-resource-group-senior-storage-engineer
# 2              True         ecs-resource-group-splunk-consultant
# 3             False              irdeto-senior-software-engineer
# 4             False            irdeto-junior-analyst-anti-piracy
#
#                                     employment_types  \
# 0  [{'type': 'b2b', 'salary': {'from': 9000, 'to'...
# 1  [{'type': 'b2b', 'salary': {'from': 18000, 'to...
# 2  [{'type': 'b2b', 'salary': {'from': 22000, 'to...
# 3            [{'type': 'permanent', 'salary': None}]
# 4     [{'type': 'mandate_contract', 'salary': None}]
#
#                                     company_logo_url  \
# 0  https://bucket.justjoin.it/offers/company_logo...
# 1  https://bucket.justjoin.it/offers/company_logo...
# 2  https://bucket.justjoin.it/offers/company_logo...
# 3  https://bucket.justjoin.it/offers/company_logo...
# 4  https://bucket.justjoin.it/offers/company_logo...
#
#                                               skills  remote
# 0  [{'name': 'Node.js', 'level': 4}, {'name': 'Ja...    True
# 1  [{'name': 'EMC', 'level': 4}, {'name': 'NAS', ...   False
# 2                   [{'name': 'Splunk', 'level': 5}]   False
# 3  [{'name': 'Node.js', 'level': 3}, {'name': 'Ku...   False
# 4  [{'name': 'PC', 'level': 2}, {'name': 'CSS', '...   False

# %% [markdown]
# # Basic informations

# %%
df.head()
# Out:
#                                      title                    street  \
# 0  Fullstack Dev. - Swedish dating startup             Marszałkowska
# 1                  Senior Storage Engineer                  Basztowa
# 2                        Splunk Consultant                  Basztowa
# 3                 Senior Software Engineer  Poznań, ul. Piłsudskiego
# 4              Junior Analyst: Anti-Piracy  Poznań, ul. Piłsudskiego
#
#        city country_code                       address_text marker_icon  \
# 0  Warszawa           PL            Marszałkowska, Warszawa  javascript
# 1    Kraków           PL                   Basztowa, Kraków       other
# 2    Kraków           PL                   Basztowa, Kraków    security
# 3   Wrocław           PL  Poznań, ul. Piłsudskiego, Wrocław      devops
# 4   Wrocław           PL  Poznań, ul. Piłsudskiego, Wrocław    security
#
#   workplace_type        company_name                 company_url company_size  \
# 0         remote              Relate  https://www.relate-app.com         2-10
# 1  partly_remote  ECS Resource Group  https://theecsgroup.co.uk/      10,000+
# 2  partly_remote  ECS Resource Group  https://theecsgroup.co.uk/      10,000+
# 3  partly_remote              Irdeto       http://www.irdeto.com         1000
# 4  partly_remote              Irdeto       http://www.irdeto.com         1000
#
#   experience_level    latitude   longitude              published_at  \
# 0              mid   52.228181  21.0125682  2021-03-23T12:05:00.000Z
# 1              mid   50.066114  19.9406042  2021-03-23T12:04:00.000Z
# 2           senior   50.066114  19.9406042  2021-03-23T12:04:00.000Z
# 3           senior  51.0997775  17.0347608  2021-03-23T11:42:00.000Z
# 4           junior  51.0997775  17.0347608  2021-03-23T11:42:00.000Z
#
#    remote_interview                                           id  \
# 0             False  relate-fullstack-developer-and-head-of-data
# 1              True   ecs-resource-group-senior-storage-engineer
# 2              True         ecs-resource-group-splunk-consultant
# 3             False              irdeto-senior-software-engineer
# 4             False            irdeto-junior-analyst-anti-piracy
#
#                                     employment_types  \
# 0  [{'type': 'b2b', 'salary': {'from': 9000, 'to'...
# 1  [{'type': 'b2b', 'salary': {'from': 18000, 'to...
# 2  [{'type': 'b2b', 'salary': {'from': 22000, 'to...
# 3            [{'type': 'permanent', 'salary': None}]
# 4     [{'type': 'mandate_contract', 'salary': None}]
#
#                                     company_logo_url  \
# 0  https://bucket.justjoin.it/offers/company_logo...
# 1  https://bucket.justjoin.it/offers/company_logo...
# 2  https://bucket.justjoin.it/offers/company_logo...
# 3  https://bucket.justjoin.it/offers/company_logo...
# 4  https://bucket.justjoin.it/offers/company_logo...
#
#                                               skills  remote
# 0  [{'name': 'Node.js', 'level': 4}, {'name': 'Ja...    True
# 1  [{'name': 'EMC', 'level': 4}, {'name': 'NAS', ...   False
# 2                   [{'name': 'Splunk', 'level': 5}]   False
# 3  [{'name': 'Node.js', 'level': 3}, {'name': 'Ku...   False
# 4  [{'name': 'PC', 'level': 2}, {'name': 'CSS', '...   False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3868 entries, 0 to 3867
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             3868 non-null   object
#  1   street            3857 non-null   object
#  2   city              3868 non-null   object
#  3   country_code      3864 non-null   object
#  4   address_text      3868 non-null   object
#  5   marker_icon       3868 non-null   object
#  6   workplace_type    3868 non-null   object
#  7   company_name      3868 non-null   object
#  8   company_url       3868 non-null   object
#  9   company_size      3868 non-null   object
#  10  experience_level  3868 non-null   object
#  11  latitude          3868 non-null   object
#  12  longitude         3868 non-null   object
#  13  published_at      3868 non-null   object
#  14  remote_interview  3868 non-null   bool
#  15  id                3868 non-null   object
#  16  employment_types  3868 non-null   object
#  17  company_logo_url  3868 non-null   object
#  18  skills            3868 non-null   object
#  19  remote            3868 non-null   bool
# dtypes: bool(2), object(18)
# memory usage: 551.6+ KB

# %% [markdown]
# # Null values

# %%
df.isnull().sum()
# Out:
# title                0
# street              11
# city                 0
# country_code         4
# address_text         0
# marker_icon          0
# workplace_type       0
# company_name         0
# company_url          0
# company_size         0
# experience_level     0
# latitude             0
# longitude            0
# published_at         0
# remote_interview     0
# id                   0
# employment_types     0
# company_logo_url     0
# skills               0
# remote               0
# dtype: int64

# %%
df.loc[df['country_code'].isnull() == True]
# Out:
#                                    title         street      city  \
# 321   Senior Java Developer with Russian  Marszałkowska  Warszawa
# 1131               Senior Data Scientist  Marynarska 12  Warszawa
# 1949           Site Reliability Engineer        Centrum  Warszawa
# 1985            Senior Shopify Developer      Wołoska 9  Warszawa
#
#      country_code             address_text marker_icon workplace_type  \
# 321          None  Marszałkowska, Warszawa        java         remote
# 1131         None  Marynarska 12, Warszawa        data         remote
# 1949         None        Centrum, Warszawa      devops         remote
# 1985         None      Wołoska 9, Warszawa        html         remote
#
#               company_name                company_url company_size  \
# 321               ZeptoLab  https://www.zeptolab.com/          120
# 1131  T-Mobile Polska S.A.   https://www.t-mobile.pl/         4500
# 1949        EliteHunter.pl  http://www.elitehunter.pl            2
# 1985    Relyon IT Services       https://rits.center/          300
#
#      experience_level    latitude   longitude              published_at  \
# 321            senior   52.228181  21.0125682  2021-03-22T16:11:00.000Z
# 1131           senior   51.921253   19.145759  2021-03-21T12:00:09.883Z
# 1949              mid  52.2293754  21.0131961  2021-03-19T13:44:00.000Z
# 1985           senior   51.921253   19.145759  2021-03-19T13:00:08.883Z
#
#       remote_interview                                                 id  \
# 321               True        zeptolab-senior-java-developer-with-russian
# 1131             False  t-mobile-polska-s-a-senior-data-scientist-ad42...
# 1949              True           elitehunter-pl-site-reliability-engineer
# 1985              True        relyon-it-services-senior-shopify-developer
#
#                                        employment_types  \
# 321             [{'type': 'permanent', 'salary': None}]
# 1131            [{'type': 'permanent', 'salary': None}]
# 1949  [{'type': 'permanent', 'salary': {'from': 1700...
# 1985  [{'type': 'b2b', 'salary': {'from': 15000, 'to...
#
#                                        company_logo_url  \
# 321   https://bucket.justjoin.it/offers/company_logo...
# 1131  https://bucket.justjoin.it/offers/company_logo...
# 1949  https://bucket.justjoin.it/offers/company_logo...
# 1985  https://bucket.justjoin.it/offers/company_logo...
#
#                                                  skills  remote
# 321   [{'name': 'Shell Scripting', 'level': 4}, {'na...    True
# 1131  [{'name': 'SQL', 'level': 4}, {'name': 'Data S...    True
# 1949  [{'name': 'Kubernetes', 'level': 3}, {'name': ...    True
# 1985  [{'name': 'HTML', 'level': 4}, {'name': 'CSS',...    True

# %%
df['country_code'] = df['country_code'].fillna('PL')

# %%
df.head()
# Out:
#                                      title                    street  \
# 0  Fullstack Dev. - Swedish dating startup             Marszałkowska
# 1                  Senior Storage Engineer                  Basztowa
# 2                        Splunk Consultant                  Basztowa
# 3                 Senior Software Engineer  Poznań, ul. Piłsudskiego
# 4              Junior Analyst: Anti-Piracy  Poznań, ul. Piłsudskiego
#
#        city country_code                       address_text marker_icon  \
# 0  Warszawa           PL            Marszałkowska, Warszawa  javascript
# 1    Kraków           PL                   Basztowa, Kraków       other
# 2    Kraków           PL                   Basztowa, Kraków    security
# 3   Wrocław           PL  Poznań, ul. Piłsudskiego, Wrocław      devops
# 4   Wrocław           PL  Poznań, ul. Piłsudskiego, Wrocław    security
#
#   workplace_type        company_name                 company_url company_size  \
# 0         remote              Relate  https://www.relate-app.com         2-10
# 1  partly_remote  ECS Resource Group  https://theecsgroup.co.uk/      10,000+
# 2  partly_remote  ECS Resource Group  https://theecsgroup.co.uk/      10,000+
# 3  partly_remote              Irdeto       http://www.irdeto.com         1000
# 4  partly_remote              Irdeto       http://www.irdeto.com         1000
#
#   experience_level    latitude   longitude              published_at  \
# 0              mid   52.228181  21.0125682  2021-03-23T12:05:00.000Z
# 1              mid   50.066114  19.9406042  2021-03-23T12:04:00.000Z
# 2           senior   50.066114  19.9406042  2021-03-23T12:04:00.000Z
# 3           senior  51.0997775  17.0347608  2021-03-23T11:42:00.000Z
# 4           junior  51.0997775  17.0347608  2021-03-23T11:42:00.000Z
#
#    remote_interview                                           id  \
# 0             False  relate-fullstack-developer-and-head-of-data
# 1              True   ecs-resource-group-senior-storage-engineer
# 2              True         ecs-resource-group-splunk-consultant
# 3             False              irdeto-senior-software-engineer
# 4             False            irdeto-junior-analyst-anti-piracy
#
#                                     employment_types  \
# 0  [{'type': 'b2b', 'salary': {'from': 9000, 'to'...
# 1  [{'type': 'b2b', 'salary': {'from': 18000, 'to...
# 2  [{'type': 'b2b', 'salary': {'from': 22000, 'to...
# 3            [{'type': 'permanent', 'salary': None}]
# 4     [{'type': 'mandate_contract', 'salary': None}]
#
#                                     company_logo_url  \
# 0  https://bucket.justjoin.it/offers/company_logo...
# 1  https://bucket.justjoin.it/offers/company_logo...
# 2  https://bucket.justjoin.it/offers/company_logo...
# 3  https://bucket.justjoin.it/offers/company_logo...
# 4  https://bucket.justjoin.it/offers/company_logo...
#
#                                               skills  remote
# 0  [{'name': 'Node.js', 'level': 4}, {'name': 'Ja...    True
# 1  [{'name': 'EMC', 'level': 4}, {'name': 'NAS', ...   False
# 2                   [{'name': 'Splunk', 'level': 5}]   False
# 3  [{'name': 'Node.js', 'level': 3}, {'name': 'Ku...   False
# 4  [{'name': 'PC', 'level': 2}, {'name': 'CSS', '...   False

# %% [markdown]
# # Add some new features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3868 entries, 0 to 3867
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             3868 non-null   object
#  1   street            3857 non-null   object
#  2   city              3868 non-null   object
#  3   country_code      3868 non-null   object
#  4   address_text      3868 non-null   object
#  5   marker_icon       3868 non-null   object
#  6   workplace_type    3868 non-null   object
#  7   company_name      3868 non-null   object
#  8   company_url       3868 non-null   object
#  9   company_size      3868 non-null   object
#  10  experience_level  3868 non-null   object
#  11  latitude          3868 non-null   object
#  12  longitude         3868 non-null   object
#  13  published_at      3868 non-null   object
#  14  remote_interview  3868 non-null   bool
#  15  id                3868 non-null   object
#  16  employment_types  3868 non-null   object
#  17  company_logo_url  3868 non-null   object
#  18  skills            3868 non-null   object
#  19  remote            3868 non-null   bool
# dtypes: bool(2), object(18)
# memory usage: 551.6+ KB

# %%
df['num_technology'] = [len(x) for x in df['skills']]

# %%
df.head()
# Out:
#                                      title                    street  \
# 0  Fullstack Dev. - Swedish dating startup             Marszałkowska
# 1                  Senior Storage Engineer                  Basztowa
# 2                        Splunk Consultant                  Basztowa
# 3                 Senior Software Engineer  Poznań, ul. Piłsudskiego
# 4              Junior Analyst: Anti-Piracy  Poznań, ul. Piłsudskiego
#
#        city country_code                       address_text marker_icon  \
# 0  Warszawa           PL            Marszałkowska, Warszawa  javascript
# 1    Kraków           PL                   Basztowa, Kraków       other
# 2    Kraków           PL                   Basztowa, Kraków    security
# 3   Wrocław           PL  Poznań, ul. Piłsudskiego, Wrocław      devops
# 4   Wrocław           PL  Poznań, ul. Piłsudskiego, Wrocław    security
#
#   workplace_type        company_name                 company_url company_size  \
# 0         remote              Relate  https://www.relate-app.com         2-10
# 1  partly_remote  ECS Resource Group  https://theecsgroup.co.uk/      10,000+
# 2  partly_remote  ECS Resource Group  https://theecsgroup.co.uk/      10,000+
# 3  partly_remote              Irdeto       http://www.irdeto.com         1000
# 4  partly_remote              Irdeto       http://www.irdeto.com         1000
#
#    ...    latitude   longitude              published_at remote_interview  \
# 0  ...   52.228181  21.0125682  2021-03-23T12:05:00.000Z            False
# 1  ...   50.066114  19.9406042  2021-03-23T12:04:00.000Z             True
# 2  ...   50.066114  19.9406042  2021-03-23T12:04:00.000Z             True
# 3  ...  51.0997775  17.0347608  2021-03-23T11:42:00.000Z            False
# 4  ...  51.0997775  17.0347608  2021-03-23T11:42:00.000Z            False
#
#                                             id  \
# 0  relate-fullstack-developer-and-head-of-data
# 1   ecs-resource-group-senior-storage-engineer
# 2         ecs-resource-group-splunk-consultant
# 3              irdeto-senior-software-engineer
# 4            irdeto-junior-analyst-anti-piracy
#
#                                     employment_types  \
# 0  [{'type': 'b2b', 'salary': {'from': 9000, 'to'...
# 1  [{'type': 'b2b', 'salary': {'from': 18000, 'to...
# 2  [{'type': 'b2b', 'salary': {'from': 22000, 'to...
# 3            [{'type': 'permanent', 'salary': None}]
# 4     [{'type': 'mandate_contract', 'salary': None}]
#
#                                     company_logo_url  \
# 0  https://bucket.justjoin.it/offers/company_logo...
# 1  https://bucket.justjoin.it/offers/company_logo...
# 2  https://bucket.justjoin.it/offers/company_logo...
# 3  https://bucket.justjoin.it/offers/company_logo...
# 4  https://bucket.justjoin.it/offers/company_logo...
#
#                                               skills remote  num_technology
# 0  [{'name': 'Node.js', 'level': 4}, {'name': 'Ja...   True               3
# 1  [{'name': 'EMC', 'level': 4}, {'name': 'NAS', ...  False               3
# 2                   [{'name': 'Splunk', 'level': 5}]  False               1
# 3  [{'name': 'Node.js', 'level': 3}, {'name': 'Ku...  False               3
# 4  [{'name': 'PC', 'level': 2}, {'name': 'CSS', '...  False               3
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Contract type

# %%
def get_contract_type(data):
    return data[0]['type']

# %%
df['contract_type'] = df['employment_types'].apply(lambda x: get_contract_type(x))

# %%
df['contract_type'].unique()
# Out:
# array(['b2b', 'permanent', 'mandate_contract'], dtype=object)

# %%
df.head()
# Out:
#                                      title                    street  \
# 0  Fullstack Dev. - Swedish dating startup             Marszałkowska
# 1                  Senior Storage Engineer                  Basztowa
# 2                        Splunk Consultant                  Basztowa
# 3                 Senior Software Engineer  Poznań, ul. Piłsudskiego
# 4              Junior Analyst: Anti-Piracy  Poznań, ul. Piłsudskiego
#
#        city country_code                       address_text marker_icon  \
# 0  Warszawa           PL            Marszałkowska, Warszawa  javascript
# 1    Kraków           PL                   Basztowa, Kraków       other
# 2    Kraków           PL                   Basztowa, Kraków    security
# 3   Wrocław           PL  Poznań, ul. Piłsudskiego, Wrocław      devops
# 4   Wrocław           PL  Poznań, ul. Piłsudskiego, Wrocław    security
#
#   workplace_type        company_name                 company_url company_size  \
# 0         remote              Relate  https://www.relate-app.com         2-10
# 1  partly_remote  ECS Resource Group  https://theecsgroup.co.uk/      10,000+
# 2  partly_remote  ECS Resource Group  https://theecsgroup.co.uk/      10,000+
# 3  partly_remote              Irdeto       http://www.irdeto.com         1000
# 4  partly_remote              Irdeto       http://www.irdeto.com         1000
#
#    ...   longitude              published_at remote_interview  \
# 0  ...  21.0125682  2021-03-23T12:05:00.000Z            False
# 1  ...  19.9406042  2021-03-23T12:04:00.000Z             True
# 2  ...  19.9406042  2021-03-23T12:04:00.000Z             True
# 3  ...  17.0347608  2021-03-23T11:42:00.000Z            False
# 4  ...  17.0347608  2021-03-23T11:42:00.000Z            False
#
#                                             id  \
# 0  relate-fullstack-developer-and-head-of-data
# 1   ecs-resource-group-senior-storage-engineer
# 2         ecs-resource-group-splunk-consultant
# 3              irdeto-senior-software-engineer
# 4            irdeto-junior-analyst-anti-piracy
#
#                                     employment_types  \
# 0  [{'type': 'b2b', 'salary': {'from': 9000, 'to'...
# 1  [{'type': 'b2b', 'salary': {'from': 18000, 'to...
# 2  [{'type': 'b2b', 'salary': {'from': 22000, 'to...
# 3            [{'type': 'permanent', 'salary': None}]
# 4     [{'type': 'mandate_contract', 'salary': None}]
#
#                                     company_logo_url  \
# 0  https://bucket.justjoin.it/offers/company_logo...
# 1  https://bucket.justjoin.it/offers/company_logo...
# 2  https://bucket.justjoin.it/offers/company_logo...
# 3  https://bucket.justjoin.it/offers/company_logo...
# 4  https://bucket.justjoin.it/offers/company_logo...
#
#                                               skills remote num_technology  \
# 0  [{'name': 'Node.js', 'level': 4}, {'name': 'Ja...   True              3
# 1  [{'name': 'EMC', 'level': 4}, {'name': 'NAS', ...  False              3
# 2                   [{'name': 'Splunk', 'level': 5}]  False              1
# 3  [{'name': 'Node.js', 'level': 3}, {'name': 'Ku...  False              3
# 4  [{'name': 'PC', 'level': 2}, {'name': 'CSS', '...  False              3
#
#       contract_type
# 0               b2b
# 1               b2b
# 2               b2b
# 3         permanent
# 4  mandate_contract
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Price

# %%
df['employment_types'][0]
# Out:
# [{'type': 'b2b', 'salary': {'from': 9000, 'to': 15000, 'currency': 'pln'}}]

# %%
def get_salary(data, label="from"):
    if data[0]['salary'] is not None:
        return data[0]['salary'][label]
    else:
        return data[0]['salary']
    
def get_currency(data):
    if data[0]['salary'] is not None:
        return data[0]['salary']['currency']
    else:
        return None

# %%
df['salary_min'] = df['employment_types'].apply(lambda x: get_salary(x))
df['salary_max'] = df['employment_types'].apply(lambda x: get_salary(x, label="to"))
df['currency'] = df['employment_types'].apply(lambda x: get_currency(x))

# %% [markdown]
# ## Skills and Technology

# %%
df['skills'] = df['skills'].apply(lambda x: list(x))

# %%
def get_skill(x):
    skills = []
    for num_skills in range(len(x)):
        try:
            skills.append(x[num_skills]['name'])
        except:
            continue
    return skills

def get_level(x):
    levels = []
    for num_skills in range(len(x)):
        try:
            levels.append(x[num_skills]['level'])
        except:
            continue
    return levels

# %%
df['technology'] = df['skills'].apply(lambda x: get_skill(x))
df['levels'] = df['skills'].apply(lambda x: get_level(x))

# %%
df.tail()
# Out:
#                                title                street       city  \
# 3863      Embedded Software Engineer               Mokotów     Warsaw
# 3864                   PHP Developer        Sierakowska 36     Poznań
# 3865  Senior Ruby on Rails Developer           Chmielna 73   Warszawa
# 3866      JavaScript/DevOps Engineer             Sienna 83   Warszawa
# 3867         Ruby on Rails Developer  Otto Mønsteds Gade 5  København
#
#      country_code                     address_text marker_icon workplace_type  \
# 3863           PL                  Mokotów, Warsaw           c  partly_remote
# 3864           PL           Sierakowska 36, Poznań         php         remote
# 3865           PL            Chmielna 73, Warszawa        ruby  partly_remote
# 3866           PL              Sienna 83, Warszawa  javascript         remote
# 3867           DK  Otto Mønsteds Gade 5, København        ruby         remote
#
#                      company_name                company_url company_size  \
# 3863                    UBUDU SAS       http://www.ubudu.com        10-15
# 3864                         Trui         http://www.trui.pl          10+
# 3865  Roomzilla Poland sp. z o.o.  https://www.roomzilla.net         5-10
# 3866                 Molecule.one      https://molecule.one/           10
# 3867                      Tjekvik         http://tjekvik.com           12
#
#       ...                                   company_logo_url  \
# 3863  ...  https://bucket.justjoin.it/offers/company_logo...
# 3864  ...  https://bucket.justjoin.it/offers/company_logo...
# 3865  ...  https://bucket.justjoin.it/offers/company_logo...
# 3866  ...  https://bucket.justjoin.it/offers/company_logo...
# 3867  ...  https://bucket.justjoin.it/offers/company_logo...
#
#                                                  skills remote num_technology  \
# 3863  [{'name': 'C', 'level': 4}, {'name': 'C++', 'l...  False              3
# 3864  [{'name': 'Git', 'level': 3}, {'name': 'Larave...   True              3
# 3865  [{'name': 'PostgreSQL', 'level': 4}, {'name': ...  False              3
# 3866  [{'name': 'CI', 'level': 4}, {'name': 'Git', '...   True              3
# 3867  [{'name': 'CSS', 'level': 1}, {'name': 'JavaSc...   True              3
#
#       contract_type salary_min salary_max currency  \
# 3863            b2b     5000.0    10000.0      pln
# 3864            b2b     8000.0    11000.0      pln
# 3865            b2b    14000.0    17000.0      pln
# 3866            b2b    14000.0    20000.0      pln
# 3867            b2b     3000.0     4000.0      eur
#
#                              technology     levels
# 3863                    [C, C++, Linux]  [4, 4, 4]
# 3864                [Git, Laravel, PHP]  [3, 3, 3]
# 3865  [PostgreSQL, Ruby on Rails, Ruby]  [4, 5, 5]
# 3866                     [CI, Git, AWS]  [4, 4, 4]
# 3867   [CSS, JavaScript, Ruby on Rails]  [1, 1, 3]
#
# [5 rows x 27 columns]

# %%
technologies = df['marker_icon'].unique()

# %%
technology_dict = {}
for technology in technologies:
    frameworks = []
    technology_df = df.loc[df['marker_icon'] == technology]['technology']
    for row in technology_df:
        frameworks.extend(row)
    technology_dict[technology] = list(set(frameworks))

# %% [markdown]
# # Drop columns

# %%
df.columns
# Out:
# Index(['title', 'street', 'city', 'country_code', 'address_text',
#        'marker_icon', 'workplace_type', 'company_name', 'company_url',
#        'company_size', 'experience_level', 'latitude', 'longitude',
#        'published_at', 'remote_interview', 'id', 'employment_types',
#        'company_logo_url', 'skills', 'remote', 'num_technology',
#        'contract_type', 'salary_min', 'salary_max', 'currency', 'technology',
#        'levels'],
#       dtype='object')

# %%
columns_to_drop = ['street', 'address_text', 'company_url', 'id', 'company_logo_url', 'employment_types', 'skills']

# %%
df = df.drop(labels=columns_to_drop, axis=1)

# %%
df.head()
# Out:
#                                      title      city country_code marker_icon  \
# 0  Fullstack Dev. - Swedish dating startup  Warszawa           PL  javascript
# 1                  Senior Storage Engineer    Kraków           PL       other
# 2                        Splunk Consultant    Kraków           PL    security
# 3                 Senior Software Engineer   Wrocław           PL      devops
# 4              Junior Analyst: Anti-Piracy   Wrocław           PL    security
#
#   workplace_type        company_name company_size experience_level  \
# 0         remote              Relate         2-10              mid
# 1  partly_remote  ECS Resource Group      10,000+              mid
# 2  partly_remote  ECS Resource Group      10,000+           senior
# 3  partly_remote              Irdeto         1000           senior
# 4  partly_remote              Irdeto         1000           junior
#
#      latitude   longitude              published_at  remote_interview  remote  \
# 0   52.228181  21.0125682  2021-03-23T12:05:00.000Z             False    True
# 1   50.066114  19.9406042  2021-03-23T12:04:00.000Z              True   False
# 2   50.066114  19.9406042  2021-03-23T12:04:00.000Z              True   False
# 3  51.0997775  17.0347608  2021-03-23T11:42:00.000Z             False   False
# 4  51.0997775  17.0347608  2021-03-23T11:42:00.000Z             False   False
#
#    num_technology     contract_type  salary_min  salary_max currency  \
# 0               3               b2b      9000.0     15000.0      pln
# 1               3               b2b     18000.0     21000.0      pln
# 2               1               b2b     22000.0     28000.0      pln
# 3               3         permanent         NaN         NaN     None
# 4               3  mandate_contract         NaN         NaN     None
#
#                             technology     levels
# 0  [Node.js, JavaScript, React Native]  [4, 4, 4]
# 1                      [EMC, NAS, SAN]  [4, 4, 4]
# 2                             [Splunk]        [5]
# 3           [Node.js, Kubernetes, AWS]  [3, 4, 4]
# 4                      [PC, CSS, HTML]  [2, 2, 2]

# %% [markdown]
# # Export new dataset

# %%
df.to_csv("../data/clear_data.csv", index=False)
